# %%
import pandas as pd
import numpy as np
import sklearn as sk

# %%
#libraries for deep learning - Tensorflow and keras
data = pd.read_excel("/content/drive/MyDrive/50_Startups.xlsx")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-f3bec07a8665> in <module>
#       1 #libraries for deep learning - Tensorflow and keras
# ----> 2 data = pd.read_excel("/content/drive/MyDrive/50_Startups.xlsx")
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
# ...

# %%
data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-304fa4ce4ebd> in <module>
# ----> 1 data.head()
#
# NameError: name 'data' is not defined

# %%
data.isnull().sum()#missing values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-b1b06d00d65d> in <module>
# ----> 1 data.isnull().sum()#missing values
#
# NameError: name 'data' is not defined

# %%
#Encoding
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
data['State'] = le.fit_transform(data['State'])

# %%
data.head()
# Out:
#    R&D Spend  Administration  Marketing Spend  State     Profit
# 0  165349.20       136897.80        471784.10      2  192261.83
# 1  162597.70       151377.59        443898.53      0  191792.06
# 2  153441.51       101145.55        407934.54      1  191050.39
# 3  144372.41       118671.85        383199.62      2  182901.99
# 4  142107.34        91391.77        366168.42      1  166187.94

# %%
y = data['Profit'] #Split dependent & independant variables
x = data.drop(columns=['Profit'],axis=1)

# %%
from sklearn.preprocessing import scale #Scale

# %%
names = x.columns

# %%
x = scale(x)

# %%
x
# Out:
# array([[ 2.01819092,  0.55696553,  2.18783528,  1.16731536],
#        [ 1.95675646,  1.0893969 ,  1.95029024, -1.23401909],
#        [ 1.75232048, -0.75766814,  1.64392865, -0.03335187],
#        [ 1.54982902, -0.1132146 ,  1.43322263,  1.16731536],
#        [ 1.49925539, -1.11632102,  1.28814125, -0.03335187],
#        [ 1.27083396, -0.806604  ,  1.25996984,  1.16731536],
#        [ 1.3319795 ,  0.93574262, -0.74312422, -1.23401909],
#        [ 1.23558377,  0.87437939,  0.92787631, -0.03335187],
#        [ 1.01776417,  0.99163696,  0.82340982,  1.16731536],
#        [ 1.08011094, -0.48065199,  0.76691751, -1.23401909],
#        [ 0.60181303, -0.4102384 ,  0.1210342 , -0.03335187],
#        [ 0.57410176, -1.10165542,  0.29637694, -1.23401909],
#        [ 0.4220906 ,  0.20479752,  0.29718526, -0.03335187],
#        [ 0.38030758,  0.50538623,  0.32125438, -1.23401909],
#        [ 1.00438367,  1.27949493,  0.35403374, -0.03335187],
# ...

# %%
x = pd.DataFrame(x,columns=names)

# %%
x.head()
# Out:
#    R&D Spend  Administration  Marketing Spend     State
# 0   2.018191        0.556966         2.187835  1.167315
# 1   1.956756        1.089397         1.950290 -1.234019
# 2   1.752320       -0.757668         1.643929 -0.033352
# 3   1.549829       -0.113215         1.433223  1.167315
# 4   1.499255       -1.116321         1.288141 -0.033352

# %%
from sklearn.model_selection import train_test_split #Split the data into traing & testing

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
#Descriiptive statistics

# %%
data.mean() #mean of each column
# Out:
# R&D Spend           74959.338704
# Administration     121750.788889
# Marketing Spend    214952.664722
# State                   1.027778
# Profit             113523.760000
# dtype: float64

# %%
data.mean(axis=1) #mean of each row
# Out:
# 0      193258.986
# 1      189933.176
# 2      170714.598
# 3      165829.574
# 4      153171.294
#           ...
# 103    133121.446
# 104    125767.144
# 105    118189.930
# 106    129536.284
# 107    125022.484
# Length: 108, dtype: float64

# %%
data.median() #mediam of each column
# Out:
# R&D Spend           75791.365
# Administration     122699.795
# Marketing Spend    239452.750
# State                   1.000
# Profit             109543.120
# dtype: float64

# %%
norm_data=pd.DataFrame(np.random.normal(size=100000))

# %%
norm_data.plot(kind="density",figsize=(10,10))

# %%
data.mode()
# Out:
#    R&D Spend  Administration  Marketing Spend  State     Profit
# 0   20229.59        91790.61              0.0    2.0  124266.90
# 1        NaN       114175.79              NaN    NaN  125370.37
# 2        NaN       121597.55              NaN    NaN  126992.93
# 3        NaN       122616.84              NaN    NaN  129917.04
# 4        NaN       127320.38              NaN    NaN  132602.65
# 5        NaN       135495.07              NaN    NaN  134307.35
# 6        NaN       145077.58              NaN    NaN  141585.52
# 7        NaN       156547.42              NaN    NaN  144259.40
